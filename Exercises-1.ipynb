# %%
# %matplotlib inline
import pandas as pd

# %%
data = pd.read_csv("H:/Data science/Assignment given/12 november/cast.csv")
data
# Out:
#                                     title  year                         name  \
# 0                          Closet Monster  2015                     Buffy #1
# 1                         Suuri illusioni  1985                       Homo $
# 2                     Battle of the Sexes  2017                      $hutter
# 3                    Secret in Their Eyes  2015                      $hutter
# 4                              Steve Jobs  2015                      $hutter
# ...                                   ...   ...                          ...
# 3611207                           Foxtrot  1988            Lilja ??risd?ttir
# 3611208  Niceland (Population. 1.000.002)  2004    Sigr??ur J?na ??risd?ttir
# 3611209                         Skammdegi  1985           Dalla ??r?ard?ttir
# 3611210                      U.S.S.S.S...  2003  Krist?n Andrea ??r?ard?ttir
# 3611211                 Bye Bye Blue Bird  1999                 Rosa ? R?gvu
#
# ...

# %%
d = data.copy()

# %%
d.isnull().sum()
# Out:
# title              0
# year               0
# name               0
# type               0
# character          0
# n            1379242
# dtype: int64

# %%
d.fillna(0,inplace=True)

# %%
d.rename(columns={'n':'rank'},inplace=True)

# %%
d
# Out:
#                                     title  year                         name  \
# 0                          Closet Monster  2015                     Buffy #1
# 1                         Suuri illusioni  1985                       Homo $
# 2                     Battle of the Sexes  2017                      $hutter
# 3                    Secret in Their Eyes  2015                      $hutter
# 4                              Steve Jobs  2015                      $hutter
# ...                                   ...   ...                          ...
# 3611207                           Foxtrot  1988            Lilja ??risd?ttir
# 3611208  Niceland (Population. 1.000.002)  2004    Sigr??ur J?na ??risd?ttir
# 3611209                         Skammdegi  1985           Dalla ??r?ard?ttir
# 3611210                      U.S.S.S.S...  2003  Krist?n Andrea ??r?ard?ttir
# 3611211                 Bye Bye Blue Bird  1999                 Rosa ? R?gvu
#
# ...

# %% [markdown]
# ### How many movies are listed in the titles dataframe?

# %%
d.shape
# Out:
# (3611212, 6)

# %%
len(d)
# Out:
# 3611212

# %% [markdown]
# ### What are the earliest two films listed in the titles dataframe?

# %%
d.head(2)
# Out:
#              title  year      name   type character  rank
# 0   Closet Monster  2015  Buffy #1  actor   Buffy 4   0.0
# 1  Suuri illusioni  1985    Homo $  actor    Guests  22.0

# %% [markdown]
# ### How many movies have the title "Hamlet"?

# %%
p=d[d.title=='Hamlet']

# %%
len(p)
# Out:
# 313

# %%
# or
p.shape
# Out:
# (313, 6)

# %% [markdown]
# ### How many movies are titled "North by Northwest"?

# %%
q = d[d.title=='North by Northwest']

# %%
len(q)
# Out:
# 112

# %%
#or
q.shape
# Out:
# (112, 6)

# %% [markdown]
# ### When was the first movie titled "Hamlet" made?

# %%
p.year.sort_values(ascending=True)
# Out:
# 1545289    1910
# 1233662    1911
# 2422953    1911
# 3015440    1911
# 1592118    1911
#            ...
# 3256505    2015
# 3137189    2015
# 3137190    2015
# 2428915    2015
# 2586749    2015
# Name: year, Length: 313, dtype: int64

# %%
#or
p.sort_values('year')
# Out:
#           title  year               name     type        character  rank
# 1545289  Hamlet  1910  Jean Mounet-Sully    actor           Hamlet   0.0
# 1233662  Hamlet  1911    Oscar Langkilde    actor          Horatio   6.0
# 2422953  Hamlet  1911   Einar Zangenberg    actor          Laertes   5.0
# 3015440  Hamlet  1911       Ella La Cour  actress         Gertrude   3.0
# 1592118  Hamlet  1911         Alwin Neu?    actor           Hamlet   1.0
# ...         ...   ...                ...      ...              ...   ...
# 3256505  Hamlet  2015       Maxine Peake  actress           Hamlet   1.0
# 3137189  Hamlet  2015        Jodie McNee  actress      Rosencrantz  10.0
# 3137190  Hamlet  2015        Jodie McNee  actress  2nd Gravedigger  10.0
# 2428915  Hamlet  2015   Ashley Zhangazha    actor          Laertes   6.0
# 2586749  Hamlet  2015  Michelle Butterly  actress         Margaret  11.0
#
# [313 rows x 6 columns]

# %%
# 1910

# %% [markdown]
# ### List all of the "Treasure Island" movies from earliest to most recent.

# %%
w =d[d.title=='Treasure Island']

# %%
w = w.sort_values('year',ascending=True)

# %%
w
# Out:
#                    title  year                  name     type  \
# 830114   Treasure Island  1918        Charles Gorman    actor
# 840745   Treasure Island  1918             Joe Grant    actor
# 909157   Treasure Island  1918          Edwin Harley    actor
# 3298306  Treasure Island  1918      Violet Radcliffe  actress
# 1715014  Treasure Island  1918            Lloyd Perl    actor
# ...                  ...   ...                   ...      ...
# 2420089  Treasure Island  1999          Caveh Zahedi    actor
# 1637661  Treasure Island  1999         Nick Offerman    actor
# 1375015  Treasure Island  1999           J.P. Manoux    actor
# 1797264  Treasure Island  1999  Victor Raider-Wexler    actor
# 307749   Treasure Island  1999          Bob Byington    actor
#
#                        character  rank
# 830114           Prologue Player   0.0
# 840745   Undetermined child role   0.0
# 909157           Prologue Player   0.0
# 3298306         Long John Silver   3.0
# ...

# %% [markdown]
# ### How many movies were made in the year 1950?

# %%
a = d[d.year==1950]

# %%
len(a)
# Out:
# 22006

# %%
a.shape
# Out:
# (22006, 6)

# %% [markdown]
# ### How many movies were made in the year 1960?

# %%
a1 = d[d.year==1960]

# %%
len(a1)
# Out:
# 18456

# %% [markdown]
# ### How many movies were made from 1950 through 1959?

# %%
d['de']=d['year']/10

# %%
d.de=d.de.astype(int)

# %%
d.de = d.de*10

# %%
d1=d.copy()

# %%
d1=d1.set_index('de')

# %%
d2=d1.loc[[1950]]

# %%
len(d2)
# Out:
# 210986

# %% [markdown]
# ### In what years has a movie titled "Batman" been released?

# %%
s=d[d.title=="Batman"]
s
# Out:
#           title  year               name     type                   character  \
# 95672    Batman  1943       Frank Austin    actor                 Hotel Clerk
# 96186    Batman  1943     William Austin    actor           Alfred Pennyworth
# 114034   Batman  1989          Del Baker    actor                 Napier Hood
# 119476   Batman  1989    Michael Balfour    actor                   Scientist
# 149767   Batman  1989         David Baxt    actor            Dr. Thomas Wayne
# ...         ...   ...                ...      ...                         ...
# 2907449  Batman  1989        Sharon Holm  actress                  Mrs. Wayne
# 3253550  Batman  1943  Shirley Patterson  actress                  Linda Page
# 3343947  Batman  1989           Pam Rose  actress  Party Guest at Wayne Manor
# 3345872  Batman  1989          Liza Ross  actress                 Tourist Mom
# 3356826  Batman  1989        Rachel Ryan  actress                      Corpse
#
#          rank    de
# ...

# %%
s.year.unique()
# Out:
# array([1943, 1989], dtype=int64)

# %%
s.year.nunique()
# Out:
# 2

# %% [markdown]
# ### How many roles were there in the movie "Inception"?

# %%
c = d[d.title=='Inception']
c
# Out:
#              title  year                  name     type  \
# 94333    Inception  2010  Michael (III) August    actor
# 143138   Inception  2010          Peter Basham    actor
# 176819   Inception  2010          Tom Berenger    actor
# 190249   Inception  2010              Ken Bhan    actor
# 250191   Inception  2010        Virgile Bramly    actor
# ...            ...   ...                   ...      ...
# 3238950  Inception  2010            Ellen Page  actress
# 3292669  Inception  2010        Nicole Pulliam  actress
# 3319073  Inception  2010    Lisa (II) Reynolds  actress
# 3325768  Inception  2010         Talulah Riley  actress
# 3560127  Inception  2010        Shannon Welles  actress
#
#                      character  rank    de
# 94333            LAX Passenger   0.0  2010
# 143138   Fischer's Jet Captain  44.0  2010
# 176819                Browning   8.0  2010
# 190249        Mombasan Gambler   0.0  2010
# 250191          Bridge Sub Con  29.0  2010
# ...

# %%
c.character.nunique()
# Out:
# 55

# %% [markdown]
# ### How many roles in the movie "Inception" are NOT ranked by an "n" value?

# %%
x = c[c['rank']==0]
x
# Out:
#              title  year                     name     type  \
# 94333    Inception  2010     Michael (III) August    actor
# 190249   Inception  2010                 Ken Bhan    actor
# 361119   Inception  2010            John Ceallach    actor
# 659835   Inception  2010            Seve Esposito    actor
# 666157   Inception  2010      Marcus (II) Everett    actor
# 682511   Inception  2010  Zachary Christopher Fay    actor
# 806524   Inception  2010        Daniel Girondeaud    actor
# 971196   Inception  2010          Andrew Hoagland    actor
# 1056651  Inception  2010          Charles Jarrell    actor
# 1069724  Inception  2010            Seong-hwan Jo    actor
# 1080743  Inception  2010          Alonzo F. Jones    actor
# 1146809  Inception  2010               Mobin Khan    actor
# 1203175  Inception  2010            Shunsaku Kud?    actor
# 1249439  Inception  2010         John (IX) Lawson    actor
# 1264919  Inception  2010    Jean-Christophe Leger    actor
# ...

# %%
len(x)
# Out:
# 26

# %% [markdown]
# ### But how many roles in the movie "Inception" did receive an "n" value?

# %%
x1 = c[c['rank']!=0]

# %%
len(x1)
# Out:
# 51

# %%
#or
len(c)-len(x)
# Out:
# 51

# %% [markdown]
# ### Display the cast of "North by Northwest" in their correct "n"-value order, ignoring roles that did not earn a numeric "n" value.

# %%
q1=q[q['rank']!=0]

# %%
q1.sort_values('rank')
# Out:
#                       title  year                  name     type  \
# 840374   North by Northwest  1959            Cary Grant    actor
# 3361396  North by Northwest  1959       Eva Marie Saint  actress
# 1404704  North by Northwest  1959           James Mason    actor
# 3024085  North by Northwest  1959   Jessie Royce Landis  actress
# 343701   North by Northwest  1959        Leo G. Carroll    actor
# 2923056  North by Northwest  1959  Josephine Hutchinson  actress
# 1634552  North by Northwest  1959           Philip Ober    actor
# 1229083  North by Northwest  1959         Martin Landau    actor
# 2357939  North by Northwest  1959         Adam Williams    actor
# 1746383  North by Northwest  1959          Edward Platt    actor
# 642085   North by Northwest  1959     Robert Ellenstein    actor
# 2212083  North by Northwest  1959          Les Tremayne    actor
# 447893   North by Northwest  1959       Philip Coolidge    actor
# ...

# %% [markdown]
# ### Display the entire cast, in "n"-order, of the 1972 film "Sleuth".

# %%
a = d[d.title=='Sleuth']
a
# Out:
#           title  year                 name     type  \
# 250297   Sleuth  2007      Kenneth Branagh    actor
# 314691   Sleuth  1972        Michael Caine    actor
# 314692   Sleuth  2007        Michael Caine    actor
# 360365   Sleuth  1972       Alec Cawthorne    actor
# 360366   Sleuth  2007  Alec (II) Cawthorne    actor
# 1246855  Sleuth  2007             Jude Law    actor
# 1396572  Sleuth  1972         Teddy Martin    actor
# 1412647  Sleuth  1972   John (II) Matthews    actor
# 1644328  Sleuth  1972     Laurence Olivier    actor
# 1741124  Sleuth  2007        Harold Pinter    actor
# 2619277  Sleuth  2007    Eve (II) Channing  actress
# 2619278  Sleuth  1972   Eve (III) Channing  actress
# 3223502  Sleuth  2007    Carmel O'Sullivan  actress
#
#                           character  rank    de
# 250297            Other Man on T.V.   0.0  2000
# 314691                  Milo Tindle   2.0  1970
# 314692                       Andrew   1.0  2000
# ...

# %%
a1 = a[a['year']==1972]

# %%
a1.sort_values('rank')
# Out:
#           title  year                name     type  \
# 1644328  Sleuth  1972    Laurence Olivier    actor
# 314691   Sleuth  1972       Michael Caine    actor
# 360365   Sleuth  1972      Alec Cawthorne    actor
# 1412647  Sleuth  1972  John (II) Matthews    actor
# 2619278  Sleuth  1972  Eve (III) Channing  actress
# 1396572  Sleuth  1972        Teddy Martin    actor
#
#                           character  rank    de
# 1644328                 Andrew Wyke   1.0  1970
# 314691                  Milo Tindle   2.0  1970
# 360365            Inspector Doppler   3.0  1970
# 1412647  Detective Sergeant Tarrant   4.0  1970
# 2619278             Marguerite Wyke   5.0  1970
# 1396572      Police Constable Higgs   6.0  1970

# %% [markdown]
# ### Now display the entire cast, in "n"-order, of the 2007 version of "Sleuth".

# %%
a2 = a[a['year']==2007]
a2
# Out:
#           title  year                 name     type          character  rank  \
# 250297   Sleuth  2007      Kenneth Branagh    actor  Other Man on T.V.   0.0
# 314692   Sleuth  2007        Michael Caine    actor             Andrew   1.0
# 360366   Sleuth  2007  Alec (II) Cawthorne    actor  Inspector Doppler   0.0
# 1246855  Sleuth  2007             Jude Law    actor               Milo   2.0
# 1741124  Sleuth  2007        Harold Pinter    actor        Man on T.V.   3.0
# 2619277  Sleuth  2007    Eve (II) Channing  actress    Marguerite Wyke   0.0
# 3223502  Sleuth  2007    Carmel O'Sullivan  actress             Maggie   0.0
#
#            de
# 250297   2000
# 314692   2000
# 360366   2000
# 1246855  2000
# 1741124  2000
# 2619277  2000
# 3223502  2000

# %%
a2.sort_values('rank')
# Out:
#           title  year                 name     type          character  rank  \
# 250297   Sleuth  2007      Kenneth Branagh    actor  Other Man on T.V.   0.0
# 360366   Sleuth  2007  Alec (II) Cawthorne    actor  Inspector Doppler   0.0
# 2619277  Sleuth  2007    Eve (II) Channing  actress    Marguerite Wyke   0.0
# 3223502  Sleuth  2007    Carmel O'Sullivan  actress             Maggie   0.0
# 314692   Sleuth  2007        Michael Caine    actor             Andrew   1.0
# 1246855  Sleuth  2007             Jude Law    actor               Milo   2.0
# 1741124  Sleuth  2007        Harold Pinter    actor        Man on T.V.   3.0
#
#            de
# 250297   2000
# 360366   2000
# 2619277  2000
# 3223502  2000
# 314692   2000
# 1246855  2000
# 1741124  2000

# %% [markdown]
# ### How many roles were credited in the silent 1921 version of Hamlet?

# %%
# f=d[d.title.str.startswith('Hamlet')]
# f

# %%
f1 = d[d.character=="Hamlet"]
f1
# Out:
#                                  title  year               name     type  \
# 6003                             Sugar  2008       Hamlet Abreu    actor
# 94018                  Top of the Town  1937        Mischa Auer    actor
# 120093             The Sound of Spying  2014      Jonathan Ball    actor
# 154451                Suivez cet avion  1989  Fran?ois Beaulieu    actor
# 154754          Nous sommes les autres  2017       Marc Beaupr?    actor
# ...                                ...   ...                ...      ...
# 2517189                       Hamlet_X  2003       Meret Becker  actress
# 2622924  Bill Shakespeare in Hollywood  2011    Rafika Chawishe  actress
# 2825750    Intikam Melegi/Kadin Hamlet  1976        Fatma Girik  actress
# 3209199                         Hamlet  1921       Asta Nielsen  actress
# 3256505                         Hamlet  2015       Maxine Peake  actress
#
#         character  rank    de
# 6003       Hamlet  58.0  2000
# ...

# %%
f2 = f1[f1.year==1921]
f2
# Out:
#           title  year          name     type character  rank    de
# 3209199  Hamlet  1921  Asta Nielsen  actress    Hamlet   1.0  1920

# %%
f2.character.count()
# Out:
# 1

# %% [markdown]
# ### How many roles were credited in Branagh’s 1996 Hamlet?

# %%
y1 = d[d['character']=='Hamlet']

# %%
y2 = y1[y1.year==1996]
y2
# Out:
#          title  year             name   type character  rank    de
# 250281  Hamlet  1996  Kenneth Branagh  actor    Hamlet   5.0  1990

# %%
y2.character.nunique()
# Out:
# 1

# %% [markdown]
# ### How many "Hamlet" roles have been listed in all film credits through history?

# %%
g = d[d.character=='Hamlet']
g
# Out:
#                                  title  year               name     type  \
# 6003                             Sugar  2008       Hamlet Abreu    actor
# 94018                  Top of the Town  1937        Mischa Auer    actor
# 120093             The Sound of Spying  2014      Jonathan Ball    actor
# 154451                Suivez cet avion  1989  Fran?ois Beaulieu    actor
# 154754          Nous sommes les autres  2017       Marc Beaupr?    actor
# ...                                ...   ...                ...      ...
# 2517189                       Hamlet_X  2003       Meret Becker  actress
# 2622924  Bill Shakespeare in Hollywood  2011    Rafika Chawishe  actress
# 2825750    Intikam Melegi/Kadin Hamlet  1976        Fatma Girik  actress
# 3209199                         Hamlet  1921       Asta Nielsen  actress
# 3256505                         Hamlet  2015       Maxine Peake  actress
#
#         character  rank    de
# 6003       Hamlet  58.0  2000
# ...

# %%
len(g)
# Out:
# 91

# %% [markdown]
# ### How many people have played an "Ophelia"?

# %%
b1=d[d.character=='Ophelia']
b1
# Out:
#                                    title  year                  name     type  \
# 238855        The Merry Maids of Madness  2016           Amy Bourque    actor
# 395196                    Jake Gets Paid  2009        Josie Chisholm    actor
# 453835                        Inoperable  2016       Crystal Cordero    actor
# 835461   Dogg's Hamlet, Cahoot's Macbeth  2005         Lucas Grabeel    actor
# 1315145                               11  2014   Catherine (IV) Lord    actor
# ...                                  ...   ...                   ...      ...
# 3538349         Hamlet, Son of a Kingpin  2015        Ingrid Vollset  actress
# 3551691                         D.C. Cab  1983       Marsha Warfield  actress
# 3552384                         Creature  2011  Jennifer Lynn Warren  actress
# 3562331                           Hamlet  2015       Katie (II) West  actress
# 3578802                           Hamlet  1996          Kate Winslet  actress
#
#         character  rank    de
# ...

# %%
b1.name.nunique()
# Out:
# 109

# %% [markdown]
# ### How many people have played a role called "The Dude"?

# %%
b2=d[d.character=="The Dude"]
b2
# Out:
#                                   title  year                  name   type  \
# 261792                 The Big Lebowski  1998          Jeff Bridges  actor
# 326893               Terms & Conditions  2015           Jordan Cann  actor
# 480810                         Stranger  2000         Scott Crowell  actor
# 549887           Pizza Man vs. the Dude  2004        Chris DeMarcus  actor
# 588962                      Sweepstakes  1931           Mike Donlin  actor
# 607151                    Self Helpless  2010        Devin The Dude  actor
# 1051244  Jay and Silent Bob Strike Back  2001   Matthew (XIX) James  actor
# 1098711                   Explicit Ills  2008    Christopher Kadish  actor
# 1317786                 American Idiots  2013      Jason Loughridge  actor
# 1336484             The Winds of Autumn  1976           Steve Lyons  actor
# 1458465                         The Liq  2016        Mark Alan Meek  actor
# ...

# %%
b2.name.nunique()
# Out:
# 18

# %% [markdown]
# ### How many people have played a role called "The Stranger"?

# %%
b3=d[d.character=="The Stranger"]
b3
# Out:
#                             title  year                       name     type  \
# 24819                       Theeb  2014  Hassan Mutlag Al-Maraiyeh    actor
# 34302              My Time to Die  2014       Vincent H. Alexander    actor
# 64774                    Get Mean  1975               Tony Anthony    actor
# 64777    Lo straniero di silenzio  1968               Tony Anthony    actor
# 64779      Un dollaro tra i denti  1967               Tony Anthony    actor
# ...                           ...   ...                        ...      ...
# 3068419              The Stranger  1995                 Kathy Long  actress
# 3081837            Ever Since Eve  1921                Ethel Lynne  actress
# 3256243              Weitertanzen  2008             Rosa Maria Paz  actress
# 3276867               The Godsend  1980           Angela Pleasence  actress
# 3407234                Motherland  1927            Dorinea Shirley  actress
#
#             character  rank    de
# ...

# %%
b3.name.nunique()
# Out:
# 197

# %% [markdown]
# ### How many roles has Sidney Poitier played throughout his career?

# %%
b4=d[d.name=="Sidney Poitier"]
b4
# Out:
#                                 title  year            name   type  \
# 1751059               A Patch of Blue  1965  Sidney Poitier  actor
# 1751060         A Piece of the Action  1977  Sidney Poitier  actor
# 1751061           A Raisin in the Sun  1961  Sidney Poitier  actor
# 1751062               A Warm December  1973  Sidney Poitier  actor
# 1751063             All the Young Men  1960  Sidney Poitier  actor
# 1751064                Band of Angels  1957  Sidney Poitier  actor
# 1751065             Blackboard Jungle  1955  Sidney Poitier  actor
# 1751066                  Brother John  1971  Sidney Poitier  actor
# 1751067         Buck and the Preacher  1972  Sidney Poitier  actor
# 1751068      Cry, the Beloved Country  1951  Sidney Poitier  actor
# 1751069                Duel at Diablo  1966  Sidney Poitier  actor
# 1751070              Edge of the City  1957  Sidney Poitier  actor
# 1751071               For Love of Ivy  1968  Sidney Poitier  actor
# ...

# %%
b4.character.nunique()
# Out:
# 41

# %% [markdown]
# ### How many roles has Judi Dench played?

# %%
b5=d[d.name=="Judi Dench"]
b5
# Out:
#                                                      title  year        name  \
# 2703455                              84 Charing Cross Road  1987  Judi Dench
# 2703456                                  A Handful of Dust  1988  Judi Dench
# 2703457                          A Midsummer Night's Dream  1968  Judi Dench
# 2703458                                 A Room with a View  1985  Judi Dench
# 2703459                                  A Study in Terror  1965  Judi Dench
# 2703460             Angelina Ballerina: Angelina Sets Sail  2006  Judi Dench
# 2703461                                      Casino Royale  2006  Judi Dench
# 2703462                                           Chocolat  2000  Judi Dench
# 2703463                                          Dead Cert  1974  Judi Dench
# 2703464                                    Die Another Day  2002  Judi Dench
# 2703465                                             Doogal  2006  Judi Dench
# ...

# %%
b5.character.nunique()
# Out:
# 46

# %% [markdown]
# ### List the supporting roles (having n=2) played by Cary Grant in the 1940s, in order by year.

# %%
r=d[d.name=='Cary Grant']
r
# Out:
#                         title  year        name   type            character  \
# 840334    Alice in Wonderland  1933  Cary Grant  actor          Mock Turtle
# 840335  An Affair to Remember  1957  Cary Grant  actor      Nickie Ferrante
# 840336   Arsenic and Old Lace  1944  Cary Grant  actor    Mortimer Brewster
# 840337         Big Brown Eyes  1936  Cary Grant  actor           Danny Barr
# 840338           Blonde Venus  1932  Cary Grant  actor        Nick Townsend
# ...                       ...   ...         ...    ...                  ...
# 840411         Walk Don't Run  1966  Cary Grant  actor  Sir William Rutland
# 840412        Wedding Present  1936  Cary Grant  actor        Charlie Mason
# 840413    When You're in Love  1937  Cary Grant  actor         Jimmy Hudson
# 840414      Wings in the Dark  1935  Cary Grant  actor           Ken Gordon
# 840415   Without Reservations  1946  Cary Grant  actor           Cary Grant
#
#         rank    de
# 840334  10.0  1930
# ...

# %%
r=r[r['rank']==2]

# %%
r.set_index('de',inplace=True)

# %%
r=r.loc[[1940]]

# %%
r.sort_values('year')
# Out:
#                  title  year        name   type    character  rank
# de
# 1940  My Favorite Wife  1940  Cary Grant  actor         Nick   2.0
# 1940    Penny Serenade  1941  Cary Grant  actor  Roger Adams   2.0

# %% [markdown]
# ### List the leading roles that Cary Grant played in the 1940s in order by year.

# %%
h=d[d.name=='Cary Grant']
h
# Out:
#                         title  year        name   type            character  \
# 840334    Alice in Wonderland  1933  Cary Grant  actor          Mock Turtle
# 840335  An Affair to Remember  1957  Cary Grant  actor      Nickie Ferrante
# 840336   Arsenic and Old Lace  1944  Cary Grant  actor    Mortimer Brewster
# 840337         Big Brown Eyes  1936  Cary Grant  actor           Danny Barr
# 840338           Blonde Venus  1932  Cary Grant  actor        Nick Townsend
# ...                       ...   ...         ...    ...                  ...
# 840411         Walk Don't Run  1966  Cary Grant  actor  Sir William Rutland
# 840412        Wedding Present  1936  Cary Grant  actor        Charlie Mason
# 840413    When You're in Love  1937  Cary Grant  actor         Jimmy Hudson
# 840414      Wings in the Dark  1935  Cary Grant  actor           Ken Gordon
# 840415   Without Reservations  1946  Cary Grant  actor           Cary Grant
#
#         rank    de
# 840334  10.0  1930
# ...

# %%
h.set_index('de',inplace=True)

# %%
h = h[h['rank']==1]

# %%
h=h.loc[[1940]]

# %%
h.sort_values('year')
# Out:
#                                      title  year        name   type  \
# de
# 1940               The Howards of Virginia  1940  Cary Grant  actor
# 1940                       His Girl Friday  1940  Cary Grant  actor
# 1940                The Philadelphia Story  1940  Cary Grant  actor
# 1940                             Suspicion  1941  Cary Grant  actor
# 1940                  The Talk of the Town  1942  Cary Grant  actor
# 1940                 Once Upon a Honeymoon  1942  Cary Grant  actor
# 1940                     Destination Tokyo  1943  Cary Grant  actor
# 1940                             Mr. Lucky  1943  Cary Grant  actor
# 1940                             Mr. Lucky  1943  Cary Grant  actor
# 1940                      Once Upon a Time  1944  Cary Grant  actor
# 1940                  Arsenic and Old Lace  1944  Cary Grant  actor
# 1940             None But the Lonely Heart  1944  Cary Grant  actor
# 1940                         Night and Day  1946  Cary Grant  actor
# ...

# %% [markdown]
# ### How many roles were available for actors in the 1950s?

# %%
t=d.set_index('de')
t
# Out:
#                                  title  year                         name  \
# de
# 2010                    Closet Monster  2015                     Buffy #1
# 1980                   Suuri illusioni  1985                       Homo $
# 2010               Battle of the Sexes  2017                      $hutter
# 2010              Secret in Their Eyes  2015                      $hutter
# 2010                        Steve Jobs  2015                      $hutter
# ...                                ...   ...                          ...
# 1980                           Foxtrot  1988            Lilja ??risd?ttir
# 2000  Niceland (Population. 1.000.002)  2004    Sigr??ur J?na ??risd?ttir
# 1980                         Skammdegi  1985           Dalla ??r?ard?ttir
# 2000                      U.S.S.S.S...  2003  Krist?n Andrea ??r?ard?ttir
# 1990                 Bye Bye Blue Bird  1999                 Rosa ? R?gvu
#
#          type                character  rank
# de
# ...

# %%
t1=t.loc[[1950]]

# %%
t1=t1[t1.type=="actor"]
t1
# Out:
#                         title  year                  name   type  \
# de
# 1950          Fire Down Below  1957  'Stretch' Cox Troupe  actor
# 1950       Dorp aan de rivier  1958         Frans 't Hoen  actor
# 1950     Ci sposeremo a Capri  1956         Quartetto 2+2  actor
# 1950           Die Todesarena  1953      Die 3 Motorellos  actor
# 1950         Palletoori Pilla  1950        Subba Rao A.V.  actor
# ...                       ...   ...                   ...    ...
# 1950         Salve sauegjeter  1958           ?yvind ?yen  actor
# 1950          La noche avanza  1952       Francisco ?beda  actor
# 1950                Yaban kiz  1954             Memduh ?n  actor
# 1950  Barbaros Hayrettin Pasa  1951          Ali ?st?ntas  actor
# 1950                 Kara Efe  1952          Ali ?st?ntas  actor
#
#                 character  rank
# de
# 1950       Limbo Dance by  20.0
# 1950             Dirk Jan  15.0
# 1950           Themselves  19.0
# 1950           Themselves   0.0
# ...

# %%
t1.character.nunique()
# Out:
# 91786

# %% [markdown]
# ### How many roles were available for actresses in the 1950s?

# %%
s=d.set_index('de')

# %%
s=s.loc[[1950]]
s
# Out:
#                       title  year                  name     type  \
# de
# 1950        Fire Down Below  1957  'Stretch' Cox Troupe    actor
# 1950     Dorp aan de rivier  1958         Frans 't Hoen    actor
# 1950   Ci sposeremo a Capri  1956         Quartetto 2+2    actor
# 1950         Die Todesarena  1953      Die 3 Motorellos    actor
# 1950       Palletoori Pilla  1950        Subba Rao A.V.    actor
# ...                     ...   ...                   ...      ...
# 1950       Styrmand Karlsen  1958            Clara ?st?  actress
# 1950       Styrmand Karlsen  1958            Clara ?st?  actress
# 1950  Tre piger fra Jylland  1957            Clara ?st?  actress
# 1950                   Toya  1956            Aslaug ?ye  actress
# 1950     Akdeniz korsanlari  1950       Muazzez ?lkerer  actress
#
#               character  rank
# de
# 1950     Limbo Dance by  20.0
# 1950           Dirk Jan  15.0
# 1950         Themselves  19.0
# 1950         Themselves   0.0
# ...

# %%
s=s[s.type=='actress']
s
# Out:
#                        title  year               name     type  \
# de
# 1950  A Woman of Distinction  1950  Lucienne & Ashour  actress
# 1950         Chain Lightning  1950  Lucienne & Ashour  actress
# 1950    De moedige bruidegom  1952     Hilda 't Seyen  actress
# 1950       Cuban Rebel Girls  1959    Beverly Aadland  actress
# 1950     Death of a Salesman  1951    Beverly Aadland  actress
# ...                      ...   ...                ...      ...
# 1950        Styrmand Karlsen  1958         Clara ?st?  actress
# 1950        Styrmand Karlsen  1958         Clara ?st?  actress
# 1950   Tre piger fra Jylland  1957         Clara ?st?  actress
# 1950                    Toya  1956         Aslaug ?ye  actress
# 1950      Akdeniz korsanlari  1950    Muazzez ?lkerer  actress
#
#                   character  rank
# de
# 1950         Apache Dancers   0.0
# 1950         Apache Dancers   0.0
# 1950  De moeder van Tinneke   0.0
# 1950          Beverly Woods   2.0
# ...

# %%
s.character.nunique()
# Out:
# 35432

# %% [markdown]
# ### How many leading roles (n=1) were available from the beginning of film history through 1980?

# %%
d2=d1[d1['rank']==1]
d2.sort_index()
# Out:
#                                                   title  year  \
# de
# 1900                 The Joe Gans-Battling Nelson Fight  1906
# 1900                     The Fairylogue and Radio-Plays  1908
# 1900                                  The Life of Moses  1909
# 1900                                      Lika mot lika  1906
# 1900                                 Robbery Under Arms  1907
# ...                                                 ...   ...
# 2020                                Gods of the Machine  2020
# 2020                               Back to the Saddle 2  2020
# 2020                                                 18  2020
# 2020                               Back to the Saddle 2  2020
# 2020  Unity, Guardians Versus Corruption: Rise of th...  2020
#
#                        name   type             character  rank
# de
# 1900               Joe Gans  actor               Himself   1.0
# 1900          L. Frank Baum  actor  The Wizard of Oz Man   1.0
# ...

# %%
d2 = d2.loc[[1900,1910,1920,1930,1940,1950,1960,1970,1980]]
d2
# Out:
#                                     title  year           name     type  \
# de
# 1900       The Fairylogue and Radio-Plays  1908  L. Frank Baum    actor
# 1900   The Joe Gans-Battling Nelson Fight  1906       Joe Gans    actor
# 1900                   Robbery Under Arms  1907     Jim Gerald    actor
# 1900                    The Life of Moses  1909   Pat Hartigan    actor
# 1900                        Lika mot lika  1906   Knut Lambert    actor
# ...                                   ...   ...            ...      ...
# 1980      Jokosei: natsu hiraku kuchiburu  1980      Ayako ?ta  actress
# 1980    Kairaku gakuen: kinjirareta asobi  1980      Ayako ?ta  actress
# 1980                         Daburu beddo  1983    Naoko ?tani  actress
# 1980  Doraemon: Nobita to tetsujin heidan  1986   Nobuyo ?yama  actress
# 1980                            Ved vejen  1988      Tammi ?st  actress
#
#                  character  rank
# de
# 1900  The Wizard of Oz Man   1.0
# ...

# %%
d2.character.nunique()
# Out:
# 59404

# %% [markdown]
# ### How many non-leading roles were available through from the beginning of film history through 1980?

# %%
d3=d1[d1['rank']!=1]
d3.sort_index()
# Out:
#                                                   title  year  \
# de
# 1890                                         Miss Jerry  1894
# 1890                                         Miss Jerry  1894
# 1890                                         Miss Jerry  1894
# 1900                        The Story of the Kelly Gang  1906
# 1900  World's Heavyweight Championship Between Tommy...  1909
# ...                                                 ...   ...
# 2020                                       Eagle Shadow  2020
# 2020                                    Irulin Vilimbil  2020
# 2020                               Echogeddon Unleashed  2020
# 2020                                                 18  2020
# 2020                                     Gordon's Quest  2020
#
#                    name     type  \
# de
# 1890    Blanche Bayliss  actress
# 1890     Chauncey Depew    actor
# 1890  William Courtenay    actor
# 1900       Mr. Marshall    actor
# 1900   Tommy (IV) Burns    actor
# ...

# %%
d3 = d3.loc[[1890,1900,1910,1920,1930,1940,1950,1960,1970,1980]]
d3
# Out:
#                                title  year                name     type  \
# de
# 1890                      Miss Jerry  1894   William Courtenay    actor
# 1890                      Miss Jerry  1894      Chauncey Depew    actor
# 1890                      Miss Jerry  1894     Blanche Bayliss  actress
# 1900  The Fairylogue and Radio-Plays  1908         Frank Burns    actor
# 1900  The Fairylogue and Radio-Plays  1908         Frank Burns    actor
# ...                              ...   ...                 ...      ...
# 1980                        Kavgamiz  1989            Nil ?nal  actress
# 1980                  Sevimli Hirsiz  1988            Nil ?nal  actress
# 1980                  Candan sevmeli  1985       Ayseg?l ?nsal  actress
# 1980                         Foxtrot  1988   Lilja ??risd?ttir  actress
# 1980                       Skammdegi  1985  Dalla ??r?ard?ttir  actress
#
#                                               character  rank
# de
# ...

# %%
d3.character.nunique()
# Out:
# 665783

# %% [markdown]
# ### How many roles through 1980 were minor enough that they did not warrant a numeric "n" rank?

# %%
d4=d1[d1['rank']==0]
d4.sort_index()
# Out:
#                                        title  year                   name  \
# de
# 1890                              Miss Jerry  1894      William Courtenay
# 1890                              Miss Jerry  1894        Blanche Bayliss
# 1890                              Miss Jerry  1894         Chauncey Depew
# 1900                       Gans-Nelson Fight  1908               Joe Gans
# 1900             The Story of the Kelly Gang  1906           Mr. Marshall
# ...                                      ...   ...                    ...
# 2020  The Windwater Pack: Homebound Drifters  2020         Conrad Pallman
# 2020  The Windwater Pack: Homebound Drifters  2020      Andrew M. Fleming
# 2020                             Romantos II  2020  Khrystale Otero-Abaya
# 2020                       The Burning Skies  2022         Caleb Vladicka
# 2020                Death Sentence: Fan Film  2020          Jennie Weldon
#
#          type                                          character  rank
# de
# ...

# %%
d4 = d4.loc[[1890,1900,1910,1920,1930,1940,1950,1960,1970,1980]]
d4
# Out:
#                                                   title  year  \
# de
# 1890                                         Miss Jerry  1894
# 1890                                         Miss Jerry  1894
# 1890                                         Miss Jerry  1894
# 1900  World's Heavyweight Championship Between Tommy...  1909
# 1900                        The Story of the Kelly Gang  1906
# ...                                                 ...   ...
# 1980                                   Kamilla og tyven  1988
# 1980                                Kamilla og tyven II  1989
# 1980                                           Piratene  1983
# 1980                                  Seytanin ogullari  1987
# 1980                                     Candan sevmeli  1985
#
#                       name     type  \
# de
# 1890     William Courtenay    actor
# 1890        Chauncey Depew    actor
# 1890       Blanche Bayliss  actress
# 1900      Tommy (IV) Burns    actor
# ...

# %%
d4.character.nunique()
# Out:
# 210287
